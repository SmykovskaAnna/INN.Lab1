# %% [markdown]
# <a href="https://colab.research.google.com/github/SmykovskaAnna/INN.Lab1/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1-9

# %%
import pandas as pd
df = pd.read_csv('car_price_dataset.csv')
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df[df['Brand']=='Chevrolet']
# Out:
#           Brand    Model  Year  Engine_Size Fuel_Type    Transmission  \
# 1     Chevrolet   Malibu  2012          2.0    Hybrid       Automatic
# 20    Chevrolet  Equinox  2018          1.8    Hybrid       Automatic
# 29    Chevrolet  Equinox  2013          1.9    Hybrid       Automatic
# 32    Chevrolet   Impala  2017          2.3    Petrol       Automatic
# 56    Chevrolet   Impala  2017          1.8    Diesel  Semi-Automatic
# ...         ...      ...   ...          ...       ...             ...
# 9956  Chevrolet  Equinox  2003          4.7  Electric          Manual
# 9960  Chevrolet   Malibu  2013          1.5    Diesel  Semi-Automatic
# 9969  Chevrolet  Equinox  2016          3.9  Electric       Automatic
# 9970  Chevrolet   Impala  2022          1.1    Hybrid  Semi-Automatic
# 9996  Chevrolet   Impala  2002          1.4  Electric       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 1        5356      2            3  12092
# 20      21261      2            1  13374
# ...

# %%
df[df['Brand']!='Chevrolet']
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 5         Toyota     Camry  2007          2.7    Petrol       Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9994       Honda     Civic  2016          2.9    Petrol          Manual
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df[df['Brand'].isin(['Audi', 'BMW'])]
# Out:
#      Brand     Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 3     Audi        Q5  2023          2.0  Electric          Manual   160971
# 10     BMW  5 Series  2013          1.3    Hybrid       Automatic   296824
# 26    Audi        A3  2022          3.3  Electric          Manual    79350
# 27     BMW  3 Series  2017          2.3  Electric  Semi-Automatic   142701
# 28     BMW  3 Series  2020          4.7  Electric  Semi-Automatic   210767
# ...    ...       ...   ...          ...       ...             ...      ...
# 9987   BMW  5 Series  2004          1.3    Diesel          Manual    19392
# 9988   BMW  3 Series  2010          3.0    Diesel          Manual   105615
# 9990  Audi        A3  2019          1.8  Electric          Manual    85496
# 9992   BMW  5 Series  2016          1.2    Hybrid       Automatic    13386
# 9997   BMW  3 Series  2010          3.0    Petrol       Automatic    86664
#
#       Doors  Owner_Count  Price
# 3         2            1  11780
# ...

# %%
df[df['Price'].astype(int) >= 8000]
# Out:
#           Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0           Kia       Rio  2020          4.2    Diesel          Manual
# 1     Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2      Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3          Audi        Q5  2023          2.0  Electric          Manual
# 6         Honda     Civic  2010          3.4  Electric       Automatic
# ...         ...       ...   ...          ...       ...             ...
# 9991   Mercedes   E-Class  2017          1.1    Diesel       Automatic
# 9992        BMW  5 Series  2016          1.2    Hybrid       Automatic
# 9993      Honda    Accord  2019          4.7    Hybrid  Semi-Automatic
# 9995        Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9997        BMW  3 Series  2010          3.0    Petrol       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df[df['Price'].astype(int) <= 8000]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 5         Toyota     Camry  2007          2.7    Petrol       Automatic
# 7            Kia  Sportage  2001          4.7  Electric  Semi-Automatic
# 9         Toyota      RAV4  2005          3.1    Petrol          Manual
# 10           BMW  5 Series  2013          1.3    Hybrid       Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9989      Toyota   Corolla  2003          1.6    Diesel  Semi-Automatic
# 9994       Honda     Civic  2016          2.9    Petrol          Manual
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 4      286618      3            3   2867
# ...

# %%
df[(df['Price'].astype(int) <= 5000) & (df['Price'].astype(int) >= 2500)]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 13       Hyundai   Elantra  2004          2.3    Hybrid  Semi-Automatic
# 37           Kia  Sportage  2000          1.4  Electric          Manual
# 39          Audi        A4  2004          1.0    Petrol          Manual
# 46          Audi        A4  2009          2.4    Diesel          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9981         Kia       Rio  2003          4.3    Petrol  Semi-Automatic
# 9982        Ford    Fiesta  2000          1.5    Hybrid  Semi-Automatic
# 9986        Audi        A4  2005          3.6    Petrol  Semi-Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 4      286618      3            3   2867
# ...

# %%
df = pd.DataFrame({'Brand': df['Brand']})
df.to_csv('out.csv', index=False)

# %%
import numpy as np
age_male = np.random.uniform(low=20, high=30, size=(1,50)).flatten()
age_female =np.random.uniform(low=20, high=30, size=(1,50)).flatten()
df = pd.DataFrame({"age_female": age_female, "age_male": age_male})
df.to_csv('out.csv', index=False)

# %% [markdown]
# # Завдання 10-12

# %%
import plotly.express as px
df = pd.read_csv('car_price_dataset.csv')
print(df.head())
fig = px.line(df, x="Year", y="Price", color='Model')
fig.show()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
partial = df[df['Model'].isin(['Rio', 'Malibu'])]
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
partial = df[df['Model']=='Rio']
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
partial = df[df['Model']!='Rio']
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
partial = df[df['Year'].astype(int) >= 2000]
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
partial = df[df['Year'].astype(int) <= 2010]
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
partial = df[(df['Year'].astype(int) <= 2005) & (df['Year'].astype(int) >= 2000)]
fig = px.line(partial, x="Year", y="Price", color="Model")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
df = pd.read_csv('iris.csv')
print(df.head())
df
fig = px.scatter_3d(df, x="Sepal Length (cm)", y="Sepal Width (cm)", z='Petal Width (cm)', color='Species')
fig.show()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %% [markdown]
# # Завдання 13-15

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models

# First
df = pd.read_csv('alarms.csv')
fig = px.scatter_3d(df, x='sound', y='visibility', z='alarm')
fig.show()
# Second
x = df[['sound', 'distance', 'visibility']].values
y = df['alarm'].values
# Third
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
# Fouth
model = models.Sequential([layers.Dense(1,input_shape=(x_train.shape[1],), activation='sigmoid')])
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
# Fifth
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
# Sixth
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Seven
new_data = np.array([
    [0.7, 0.1, 0.7],
    [0.3, 0.7, 0.3],
    [0.4, 0.5, 0.3],
    [0.6, 0.5, 0.7],
    [0.9, 0.1, 0.9],
])
predictions = model.predict(new_data)
print("Predictions:")
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predictions:
# [[0.59872216]
#  [0.3786504 ]
#  [0.43128225]
#  [0.51283723]
#  [0.6576116 ]]
